# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/tidyverse/ggplot2/master/data-raw/diamonds.csv'
dia = pd.read_csv(url)
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %% [markdown]
# no missing data

# %%
dia.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# x,y,z merupakan panjang, lebar, dan kedalaman sehingga tidak memungkinkan nilai min nya itu 0

# %%
x = (dia.x == 0).sum()
y = (dia.y == 0).sum()
z = (dia.z == 0).sum()

print("Nilai 0 di kolom x ada di: ", x)
print("Nilai 0 di kolom y ada di: ", y)
print("Nilai 0 di kolom z ada di: ", z)
# Out:
# Nilai 0 di kolom x ada di:  8
# Nilai 0 di kolom y ada di:  7
# Nilai 0 di kolom z ada di:  20

# %%
dia.loc[(dia['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %% [markdown]
# seluruh data bernilai 0 pada dimensi x dan y juga memiliki nilai 0 pada dimensi z

# %%
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# kita drop invalid data z=0 karena sudah mewakili nilai x dan y yang 0

# %%
dia = dia.loc[(dia[['z']] != 0).all(axis=1)]

# cek ukuran
dia.shape
# Out:
# (53920, 10)

# %%
dia.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.boxplot(x=dia['carat'])
# Out:
# <Axes: xlabel='carat'>

# %%
sns.boxplot(x=dia['table'])
# Out:
# <Axes: xlabel='table'>

# %%
sns.boxplot(x=dia['x'])
# Out:
# <Axes: xlabel='x'>

# %%
# Select only numeric columns
numeric_cols = dia.select_dtypes(include=[np.number]).columns

Q1 = dia[numeric_cols].quantile(0.25)
Q3 = dia[numeric_cols].quantile(0.75)
IQR = Q3 - Q1  # IQR is interquartile range.

dia = dia[~((dia[numeric_cols] < (Q1 - 1.5 * IQR)) | (dia[numeric_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# cek ukuran
dia.shape
# Out:
# (47524, 10)

# %%
numerical_features = ['price', 'carat', 'depth', 'table', 'x', 'y', 'z']
category_features = ['cut', 'color', 'clarity']

# %%
feature = category_features[0]
count = dia[feature].value_counts()
percent = 100*dia[feature].value_counts(normalize=True)
df = pd.DataFrame({'Jumlah Sampel': count, 'persentase': percent.round(1)})
print(df)
count.plot(kind='bar', title=feature);
# Out:
#            Jumlah Sampel  persentase
# cut
# Ideal              20340        42.8
# Premium            12115        25.5
# Very Good          10994        23.1
# Good                3745         7.9
# Fair                 330         0.7

# %%
feature = category_features[1]
count = dia[feature].value_counts()
percent = 100*dia[feature].value_counts(normalize=True)
df = pd.DataFrame({'Jumlah Sampel': count, 'persentase': percent.round(1)})
print(df)
count.plot(kind='bar', title=feature);
# Out:
#        Jumlah Sampel  persentase
# color
# G              10081        21.2
# E               8910        18.7
# F               8466        17.8
# H               7176        15.1
# D               6195        13.0
# I               4462         9.4
# J               2234         4.7

# %%
feature = category_features[2]
count = dia[feature].value_counts()
percent = 100*dia[feature].value_counts(normalize=True)
df = pd.DataFrame({'Jumlah Sampel': count, 'persentase': percent.round(1)})
print(df)
count.plot(kind='bar', title=feature);
# Out:
#          Jumlah Sampel  persentase
# clarity
# SI1              11552        24.3
# VS2              10928        23.0
# SI2               7402        15.6
# VS1               7373        15.5
# VVS2              4683         9.9
# VVS1              3463         7.3
# IF                1650         3.5
# I1                 473         1.0

# %%
dia.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Pada plot *Price* kita bisa lihat bahwa jika semakin banyak jumlah sampel maka nilai atau harga dari _Diamonds_ tersebut akan mengalami penurunan
